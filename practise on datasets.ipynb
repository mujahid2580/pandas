# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
import scipy

# %%
import pandas_profiling

# %%
d= pd.read_csv(r"C:\Users\LENOVO\Desktop\anantapur rainfall.csv")

# %%
d
# Out:
#     Dmcode       Mandal  Cumm Actual Rainfall  Cumm Normal Rainfall  \
# 0      NaN          NaN                   NaN                   NaN
# 1   1201.0    D Hirchal                 508.5                 359.4
# 2   1202.0   Bommanahal                 479.6                 353.5
# 3   1203.0  Vidapanakal                 464.7                 513.0
# 4   1204.0   Vajrakarur                 456.0                 467.3
# ..     ...          ...                   ...                   ...
# 59  1259.0   Madakasira                 587.6                 491.8
# 60  1260.0    Gudibanda                 563.5                 452.1
# 61  1261.0   Amarapuram                 743.8                 482.5
# 62  1262.0        Agali                 615.2                 511.8
# 63  1263.0        Rolla                 527.1                 549.9
#
#     Deviation  Status            Predominant Crops Irrigation(area)
# 0         NaN     NaN                          NaN              NaN
# ...

# %%
d.isna().sum()
# Out:
# Dmcode                  1
# Mandal                  1
# Cumm Actual Rainfall    1
# Cumm Normal Rainfall    1
# Deviation               1
# Status                  1
# Predominant Crops       1
# Irrigation(area)        1
# dtype: int64

# %%
d.replace((" ",np.nan),inplace=True)
# Out:
# Dmcode                  None
# Mandal                  None
# Cumm Actual Rainfall    None
# Cumm Normal Rainfall    None
# Deviation               None
# Status                  None
# Predominant Crops       None
# Irrigation(area)        None
# dtype: object

# %%
d.isna().sum()
# Out:
# Dmcode                  1
# Mandal                  1
# Cumm Actual Rainfall    1
# Cumm Normal Rainfall    1
# Deviation               1
# Status                  1
# Predominant Crops       1
# Irrigation(area)        1
# dtype: int64

# %%
d.dropna((0),inplace=True)

# %%
d
# Out:
#     Dmcode       Mandal  Cumm Actual Rainfall  Cumm Normal Rainfall  \
# 1   1201.0    D Hirchal                 508.5                 359.4
# 2   1202.0   Bommanahal                 479.6                 353.5
# 3   1203.0  Vidapanakal                 464.7                 513.0
# 4   1204.0   Vajrakarur                 456.0                 467.3
# 5   1205.0     Guntakal                 434.9                 471.3
# ..     ...          ...                   ...                   ...
# 59  1259.0   Madakasira                 587.6                 491.8
# 60  1260.0    Gudibanda                 563.5                 452.1
# 61  1261.0   Amarapuram                 743.8                 482.5
# 62  1262.0        Agali                 615.2                 511.8
# 63  1263.0        Rolla                 527.1                 549.9
#
#     Deviation  Status            Predominant Crops Irrigation(area)
# 1        41.5  Excess       Groundnut,Rice,Redgram          command
# ...

# %%
d.isna().sum()
# Out:
# Dmcode                  0
# Mandal                  0
# Cumm Actual Rainfall    0
# Cumm Normal Rainfall    0
# Deviation               0
# Status                  0
# Predominant Crops       0
# Irrigation(area)        0
# dtype: int64

# %%
d.head(30).isna().sum()
# Out:
# Dmcode                  0
# Mandal                  0
# Cumm Actual Rainfall    0
# Cumm Normal Rainfall    0
# Deviation               0
# Status                  0
# Predominant Crops       0
# Irrigation(area)        0
# dtype: int64

# %%
d.tail(38).isna().sum()
# Out:
# Dmcode                  0
# Mandal                  0
# Cumm Actual Rainfall    0
# Cumm Normal Rainfall    0
# Deviation               0
# Status                  0
# Predominant Crops       0
# Irrigation(area)        0
# dtype: int64

# %%
d.describe()
# Out:
#             Dmcode  Cumm Actual Rainfall  Cumm Normal Rainfall  Deviation
# count    63.000000             63.000000             63.000000  63.000000
# mean   1232.000000            516.187302            496.660317   6.719048
# std      18.330303             94.962353             78.055304  26.453171
# min    1201.000000            314.800000            306.600000 -41.700000
# 25%    1216.500000            449.600000            449.300000 -10.150000
# 50%    1232.000000            508.000000            511.800000   4.600000
# 75%    1247.500000            579.750000            551.200000  19.700000
# max    1263.000000            760.400000            637.600000  74.200000

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 63 entries, 1 to 63
# Data columns (total 8 columns):
# Dmcode                  63 non-null float64
# Mandal                  63 non-null object
# Cumm Actual Rainfall    63 non-null float64
# Cumm Normal Rainfall    63 non-null float64
# Deviation               63 non-null float64
# Status                  63 non-null object
# Predominant Crops       63 non-null object
# Irrigation(area)        63 non-null object
# dtypes: float64(4), object(4)
# memory usage: 4.4+ KB

# %%
d.columns
# Out:
# Index(['Dmcode', 'Mandal', 'Cumm Actual Rainfall', 'Cumm Normal Rainfall',
#        'Deviation', 'Status', 'Predominant Crops', 'Irrigation(area)'],
#       dtype='object')

# %%
d.dtypes
# Out:
# Dmcode                  float64
# Mandal                   object
# Cumm Actual Rainfall    float64
# Cumm Normal Rainfall    float64
# Deviation               float64
# Status                   object
# Predominant Crops        object
# Irrigation(area)         object
# dtype: object

# %%
d.ndim
# Out:
# 2

# %%
d.shape
# Out:
# (63, 8)

# %%
d.size
# Out:
# 504

# %%
pandas_profiling.ProfileReport(d)
# Out:
#                 <iframe
#                     width="100%"
#                     height="800px"
#                     srcdoc="&lt;!doctype html&gt;
# &lt;html lang=&quot;en&quot;&gt;
# &lt;head&gt;
#     &lt;meta charset=&quot;utf-8&quot;&gt;
#     &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;
#     &lt;meta name=&quot;description&quot; content=&quot;Profile report generated with the `pandas-profiling` Python package&quot;&gt;
#     &lt;meta name=&quot;author&quot; content=&quot;Jos Polfliet, Simon Brugman and the open source community.&quot;&gt;
#     &lt;meta name=&quot;generator&quot; content=&quot;Pandas Profiling 2.2.0&quot; /&gt;
#     &lt;meta name=&quot;url&quot; content=&quot;https://github.com/pandas-profiling/pandas-profiling&quot;&gt;
#
#     &lt;title&gt;Pandas Profiling Report&lt;/title&gt;
#
# &lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
# ...

# %%
d['Status'].unique()
# Out:
# array(['Excess', 'Normal', 'Deficient'], dtype=object)

# %%
sns.heatmap(d.corr())

# %%
sns.kdeplot(d.corr())

# %%
d.mean()
# Out:
# Dmcode                  1232.000000
# Cumm Actual Rainfall     516.187302
# Cumm Normal Rainfall     496.660317
# Deviation                  6.719048
# dtype: float64

# %%
d.median()
# Out:
# Dmcode                  1232.0
# Cumm Actual Rainfall     508.0
# Cumm Normal Rainfall     511.8
# Deviation                  4.6
# dtype: float64

# %%
d.std()
# Out:
# Dmcode                  18.330303
# Cumm Actual Rainfall    94.962353
# Cumm Normal Rainfall    78.055304
# Deviation               26.453171
# dtype: float64

# %%
d.columns
# Out:
# Index(['Dmcode', 'Mandal', 'Cumm Actual Rainfall', 'Cumm Normal Rainfall',
#        'Deviation', 'Status', 'Predominant Crops', 'Irrigation(area)'],
#       dtype='object')

# %%
x=d['Cumm Actual Rainfall']
y=d['Cumm Normal Rainfall']

# %%
from scipy import stats
slope,intercept,r_value,p_value,std_error=stats.linregress(x,y)

# %%
slope
# Out:
# 0.05902771971044618

# %%
intercept
# Out:
# 466.19095810413074

# %%
r_value
# Out:
# 0.07181332824755982

# %%
p_value
# Out:
# 0.5759506257366165

# %%
std_error
# Out:
# 0.10496953529247045

# %%
plt.scatter(x,y)

# %%
plt.figure(figsize=(20,9))
plt.scatter(x,y)
plt.plot(x,slope*x+intercept,'y')
plt.xlabel('Cumm Actual Rainfall')
plt.ylabel('Cumm Normal Rainfall')
plt.title('Anantapur rainfall')
plt.show()

# %%
plt.plot(x,r_value*x+p_value,'b')
plt.show()

# %%
a=np.array(['a','b','c','d'])

# %%
a
# Out:
# array(['a', 'b', 'c', 'd'], dtype='<U1')

# %%
a.tolist().index('a')
# Out:
# 0

# %%
l = [1,2,3,4,5] # Python list
a = np.array(l) # NumPy array
i = a.tolist().index(5) # i will return index of 2
print (i)
# Out:
# 4

# %%
a.tostring()
# Out:
# b'a\x00\x00\x00b\x00\x00\x00c\x00\x00\x00d\x00\x00\x00'
